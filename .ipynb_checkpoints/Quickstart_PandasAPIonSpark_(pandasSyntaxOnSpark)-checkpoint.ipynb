# %% [markdown]
# # 2022/04/30

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps
from pyspark.sql import SparkSession
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.

# %%
s = ps.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 22/04/30 16:01:11 WARN Utils: Your hostname, SuideMacBook-Air.local resolves to a loopback address: 127.0.0.1; using 172.18.142.168 instead (on interface en0)
# 22/04/30 16:01:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/04/30 16:01:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(s)
# Out:
# pyspark.pandas.series.Series

# %% [markdown]
# ### Creating dataframe directly through the Pandas API

# %%
psdf = ps.DataFrame(
    {'a': [1, 2, 3, 4, 5, 6],
     'b': [100, 200, 300, 400, 500, 600],
     'c': ["one", "two", "three", "four", "five", "six"]},
    index=[10, 20, 30, 40, 50, 60])

# %%
psdf
# Out:
#     a    b      c
# 10  1  100    one
# 20  2  200    two
# 30  3  300  three
# 40  4  400   four
# 50  5  500   five
# 60  6  600    six

# %% [markdown]
# ### handling date ranges index

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
pdf = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
psdf = ps.from_pandas(pdf)
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
# it just works out of the box with the same built-in functions
# BUT IT"S FUCKING SPARK!!!! YAYYY

psdf.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892
# 2013-01-05 -0.638709  0.007007 -0.562074 -0.156643

# %% [markdown]
# also, it is possible to create a pandas-on-Spark DataFrame from Spark DataFrame easily
#
# creating a spark dataframe from pandas dataframe

# %%
# setting up the spark shell/session
spark = SparkSession.builder.getOrCreate()

# %%
sdf = spark.createDataFrame(pdf)

# %%
type(sdf)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
sdf.show()
# Out:
# +-------------------+--------------------+-------------------+--------------------+
# |                  A|                   B|                  C|                   D|
# +-------------------+--------------------+-------------------+--------------------+
# | 0.7768796574829357| -0.5007947003314126|0.04046548818224654|   -0.54190560600357|
# | 0.8786632766660897| 0.15767531588726855|-1.8684241002825026|  0.6398295199244199|
# | -1.290039551992367|-0.17869326552065698| 1.9449575716133252| 0.14868933403658818|
# |-1.1057338174505422|  1.3315295767961468|0.36357520034468194|  0.9028919378962661|
# |-0.6387089854216133|0.007007333214602468|-0.5620738280194325|-0.15664260151123274|
# |-0.4690624899255441|   1.047700247901684|  0.766621960535304|  0.6220382421911002|
# +-------------------+--------------------+-------------------+--------------------+

# %%
psdf2 = sdf.to_pandas_on_spark()

# %%
type(psdf2)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
type(sdf)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
psdf2.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
psdf.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq=None)

# %%
psdf.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
psdf.to_numpy()
# Out:
# array([[ 0.77687966, -0.5007947 ,  0.04046549, -0.54190561],
#        [ 0.87866328,  0.15767532, -1.8684241 ,  0.63982952],
#        [-1.29003955, -0.17869327,  1.94495757,  0.14868933],
#        [-1.10573382,  1.33152958,  0.3635752 ,  0.90289194],
#        [-0.63870899,  0.00700733, -0.56207383, -0.1566426 ],
#        [-0.46906249,  1.04770025,  0.76662196,  0.62203824]])

# %%
psdf.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.308000  0.310737  0.114187  0.269150
# std    0.929648  0.720963  1.283207  0.550851
# min   -1.290040 -0.500795 -1.868424 -0.541906
# 25%   -1.105734 -0.178693 -0.562074 -0.156643
# 50%   -0.638709  0.007007  0.040465  0.148689
# 75%    0.776880  1.047700  0.766622  0.639830
# max    0.878663  1.331530  1.944958  0.902892

# %%
psdf2.T
# Out:
# 22/04/30 16:01:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:01:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           0         1         2         3         4         5
# A  0.776880  0.878663 -1.290040 -1.105734 -0.638709 -0.469062
# B -0.500795  0.157675 -0.178693  1.331530  0.007007  1.047700
# C  0.040465 -1.868424  1.944958  0.363575 -0.562074  0.766622
# D -0.541906  0.639830  0.148689  0.902892 -0.156643  0.622038

# %%
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
type(psdf2)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
# the datetime index will prevent us from transposing
psdf
# Out:
#                    A         B         C         D
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892
# 2013-01-05 -0.638709  0.007007 -0.562074 -0.156643
# 2013-01-06 -0.469062  1.047700  0.766622  0.622038

# %%
psdf2
# Out:
# 22/04/30 16:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           A         B         C         D
# 0  0.776880 -0.500795  0.040465 -0.541906
# 1  0.878663  0.157675 -1.868424  0.639830
# 2 -1.290040 -0.178693  1.944958  0.148689
# 3 -1.105734  1.331530  0.363575  0.902892
# 4 -0.638709  0.007007 -0.562074 -0.156643
# 5 -0.469062  1.047700  0.766622  0.622038

# %%
# that's why dot T only works on psdf2

psdf2.T
# Out:
# 22/04/30 16:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:01:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           0         1         2         3         4         5
# A  0.776880  0.878663 -1.290040 -1.105734 -0.638709 -0.469062
# B -0.500795  0.157675 -0.178693  1.331530  0.007007  1.047700
# C  0.040465 -1.868424  1.944958  0.363575 -0.562074  0.766622
# D -0.541906  0.639830  0.148689  0.902892 -0.156643  0.622038

# %%
psdf.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689
# 2013-01-05 -0.638709  0.007007 -0.562074 -0.156643
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830
# 2013-01-06 -0.469062  1.047700  0.766622  0.622038
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892

# %% [markdown]
# ## Missing Data

# %% [markdown]
# pandas spark primarily uses np.nan to represent missing data. It is by default not included in computations.

# %%
pdf1 = pdf.reindex(index=dates[0:4], columns=list(pdf.columns) + ['E'])

# %%
pdf1
# Out:
#                    A         B         C         D   E
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906 NaN
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830 NaN
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689 NaN
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892 NaN

# %%
pdf
# Out:
#                    A         B         C         D
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892
# 2013-01-05 -0.638709  0.007007 -0.562074 -0.156643
# 2013-01-06 -0.469062  1.047700  0.766622  0.622038

# %%
pdf1.loc[dates[0]:dates[1], 'E'] = 1

# %%
psdf1 = ps.from_pandas(pdf1)

# %%
psdf1
# Out:
#                    A         B         C         D    E
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906  1.0
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830  1.0
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689  NaN
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892  NaN

# %% [markdown]
# drop na operations

# %%
# it's the same as how we do it in pandas
psdf1.dropna(how='any')
# Out:
#                    A         B         C         D    E
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906  1.0
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830  1.0

# %%
# fillna is also the same as pandas
psdf1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2013-01-01  0.776880 -0.500795  0.040465 -0.541906  1.0
# 2013-01-02  0.878663  0.157675 -1.868424  0.639830  1.0
# 2013-01-03 -1.290040 -0.178693  1.944958  0.148689  5.0
# 2013-01-04 -1.105734  1.331530  0.363575  0.902892  5.0

# %% [markdown]
# ## Operations

# %%
# also the same as pandas
psdf.mean()
# Out:
# A   -0.308000
# B    0.310737
# C    0.114187
# D    0.269150
# dtype: float64

# %% [markdown]
# ## Spark Configurations

# %%
prev = spark.conf.get("spark.sql.execution.arrow.pyspark.enabled")  # Keep its default value.
ps.set_option("compute.default_index_type", "distributed")  # Use default index prevent overhead.
import warnings
warnings.filterwarnings("ignore")  # Ignore warnings coming from Arrow optimizations.

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", True)

# %timeit ps.range(300000).to_pandas()
# Out:
# [Stage 47:>                                                         (0 + 8) / 8]
# 251 ms ± 56.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", False)
# %timeit ps.range(300000).to_pandas()
# Out:
# 757 ms ± 80 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
ps.reset_option("compute.default_index_type")

# using the prev that we saved earlier to reset the options
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", prev)

# %% [markdown]
# ## Grouping

# %%
psdf = ps.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})

# %%
psdf.groupby("A").sum()
# Out:
#             C         D
# A
# foo  0.134508 -0.164828
# bar  1.734116  1.032310

# %%
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
psdf.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# foo one   -0.510331  0.375954
# bar one   -0.628184 -0.552511
# foo two    0.216984 -1.282844
# bar three  1.587543  1.335488
#     two    0.774757  0.249333
# foo three  0.427856  0.742062

# %% [markdown]
# ## Plotting

# %%
pser = pd.Series(np.random.randn(1000),
                 index=pd.date_range('1/1/2000', periods=1000))

# %%
psser = ps.Series(pser)

# %%
pser
# Out:
# 2000-01-01   -0.076458
# 2000-01-02    0.146951
# 2000-01-03    0.296132
# 2000-01-04    0.219730
# 2000-01-05   -0.477165
#                 ...
# 2002-09-22   -2.043156
# 2002-09-23   -0.114466
# 2002-09-24    0.227483
# 2002-09-25    0.224636
# 2002-09-26    0.122824
# Freq: D, Length: 1000, dtype: float64

# %%
type(psser)
# Out:
# pyspark.pandas.series.Series

# %%
type(pser)
# Out:
# pandas.core.series.Series

# %%
psser = psser.cummax()

# %%
psser.plot()
# Out:
# 22/04/30 16:03:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:03:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:03:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ...

# %%
pdf = pd.DataFrame(np.random.randn(1000, 4), index=pser.index,
                   columns=['A', 'B', 'C', 'D'])

# %%
psdf = ps.from_pandas(pdf)
psdf = psdf.cummax()

# %%
psdf.plot()
# Out:
# 22/04/30 16:03:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:03:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:03:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ...

# %% [markdown]
# ## Getting data in/out

# %%
psdf.to_csv("foo_ps.csv")
ps.read_csv("foo_ps.csv").head(10)
# Out:
# 22/04/30 16:04:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:04:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:04:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:04:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:04:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           A         B         C         D
# 0  1.278688  0.879864  0.130821  0.305114
# 1  1.278688  0.879864  0.341255  0.305114
# ...

# %% [markdown]
# ### Parquet

# %%
psdf.to_parquet('bar.parquet')
ps.read_parquet('bar.parquet').head(10)
# Out:
# 22/04/30 16:05:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:05:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:05:04 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:05:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:05:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           A         B         C         D
# 0  1.278688  0.879864  0.130821  0.305114
# 1  1.278688  0.879864  0.341255  0.305114
# ...

# %% [markdown]
# ### Spark IO

# %%
psdf.to_spark_io('zoo.orc', format='orc')
ps.read_spark_io('zoo.orc', format='orc').head(10)
# Out:
# 22/04/30 16:06:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:06:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:06:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:06:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/04/30 16:06:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#           A         B         C         D
# 0  1.278688  0.879864  0.130821  0.305114
# 1  1.278688  0.879864  0.341255  0.305114
# ...
